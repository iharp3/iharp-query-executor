# %%
import sys

sys.path.append("../src")
from IPython.display import display
from query_executor_get_raster import GetRasterExecutor

metadata_fpath = "/data/iharp-customized-storage/storage/post/metadata.csv"
variable = "2m_temperature"

tests = [
    {"start": "2020-01-01 00:00", "end": "2021-02-10 20:00", "max_lat": 5, "min_lat": 1, "min_lon": 13, "max_lon": 17, "t_res": "year", "t_agg": "max", "s_res": 1, "s_agg": "min" },
    {"start": "2020-01-01 00:00", "end": "2021-02-10 20:00", "max_lat": 12, "min_lat": 8, "min_lon": 6, "max_lon": 10, "t_res": "year", "t_agg": "max", "s_res": 1, "s_agg": "min"},
    {"start": "2020-01-01 00:00", "end": "2021-02-10 20:00", "max_lat": 12, "min_lat": 8, "min_lon": 13, "max_lon": 17, "t_res": "year", "t_agg": "max", "s_res": 1, "s_agg": "min"}
]

# %%
for test in tests:
    print(f"Running test: {test}")
    qe = GetRasterExecutor(
        metadata=metadata_fpath,
        variable=variable,
        start_datetime=test["start"],
        end_datetime=test["end"],
        max_lat=test["max_lat"],
        min_lat=test["min_lat"],
        min_lon=test["min_lon"],
        max_lon=test["max_lon"],
        temporal_resolution=test["t_res"],
        temporal_aggregation=test["t_agg"],
        spatial_resolution=test["s_res"],
        spatial_aggregation=test["s_agg"],
    )
    res = qe.compute()
    display(res)
# Out:
# Running test: {'start': '2020-01-01 00:00', 'end': '2021-02-10 20:00', 'max_lat': 5, 'min_lat': 1, 'min_lon': 13, 'max_lon': 17, 't_res': 'year', 't_agg': 'max', 's_res': 1, 's_agg': 'min'}
# local files: ['/data/iharp-customized-storage/storage/post/2m_temperature_t1_s2_1733635806997_max_min_post.nc']
# ...
