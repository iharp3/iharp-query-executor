# %%
import sys

sys.path.append("../src")
from IPython.display import display
from query_executor_get_raster import GetRasterExecutor

metadata_fpath = "/data/iharp-customized-storage/storage/post/metadata.csv"
variable = "2m_temperature"
start_datetime = "2020-01-01 00:00"
end_datetime = "2020-12-31 23:00"

tests = [
    {"max_lat": 9, "min_lat": 1, "min_lon": 6, "max_lon": 14, "t_res": "year", "t_agg": "max", "s_res": 1, "s_agg": "min"},
    {"max_lat": 8.8, "min_lat": 1, "min_lon": 6, "max_lon": 14, "t_res": "year", "t_agg": "max", "s_res": 1, "s_agg": "min"},
    {"max_lat": 8.6, "min_lat": 1, "min_lon": 6, "max_lon": 14, "t_res": "year", "t_agg": "max", "s_res": 1, "s_agg": "min"},
    {"max_lat": 8.4, "min_lat": 1, "min_lon": 6, "max_lon": 14, "t_res": "year", "t_agg": "max", "s_res": 1, "s_agg": "min"},
    {"max_lat": 8.8, "min_lat": 1, "min_lon": 6.2, "max_lon": 14, "t_res": "year", "t_agg": "max", "s_res": 1, "s_agg": "min"},
    {"max_lat": 8.6, "min_lat": 1, "min_lon": 6.4, "max_lon": 14, "t_res": "year", "t_agg": "max", "s_res": 1, "s_agg": "min"},
    {"max_lat": 8.4, "min_lat": 1, "min_lon": 6.6, "max_lon": 14, "t_res": "year", "t_agg": "max", "s_res": 1, "s_agg": "min"}
]

# %%
for test in tests:
    print(f"Running test: {test}")
    qe = GetRasterExecutor(
        metadata=metadata_fpath,
        variable=variable,
        start_datetime=start_datetime,
        end_datetime=end_datetime,
        max_lat=test["max_lat"],
        min_lat=test["min_lat"],
        min_lon=test["min_lon"],
        max_lon=test["max_lon"],
        temporal_resolution=test["t_res"],
        temporal_aggregation=test["t_agg"],
        spatial_resolution=test["s_res"],
        spatial_aggregation=test["s_agg"],
    )
    res = qe.compute()
    display(res)
# Out:
# Running test: {'max_lat': 9, 'min_lat': 1, 'min_lon': 6, 'max_lon': 14, 't_res': 'year', 't_agg': 'max', 's_res': 1, 's_agg': 'min'}
# local files: ['/data/iharp-customized-storage/storage/post/2m_temperature_t1_s2_1733635806997_max_min_post.nc']
# api: []
# <xarray.Dataset> Size: 648B
# Dimensions:    (time: 1, latitude: 8, longitude: 8)
# Coordinates:
#   * latitude   (latitude) float64 64B 8.625 7.625 6.625 ... 3.625 2.625 1.625
#   * longitude  (longitude) float64 64B 6.375 7.375 8.375 ... 11.38 12.38 13.38
#   * time       (time) datetime64[ns] 8B 2020-12-31
# Data variables:
#     t2m        (time, latitude, longitude) float64 512B 313.0 311.8 ... 308.3
# Attributes:
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
# ...
